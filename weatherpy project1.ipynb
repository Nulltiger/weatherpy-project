# %%
#Dependencies
from citipy import citipy
from config import API
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json

# %%
#Randomly generate latitude and longitude numbers. lookup nearest city using citipy

# Empty list to hold cities and countries. Also loop counter to ensure 500 is completed.
random_city = []
random_country = []
loopcounter = 0

# %%
#Loop until 500 cities are identified
while len(random_city) < 500 :
    
    loopcounter +=1
    
    # Randomly generate latitude
    lat_pos = random.randint(0,2)
    base_lat = random.randint(0,91)
    dec_lat = random.random()/100
    lat = base_lat + dec_lat
    if lat_pos == 1:
        lat = lat * -1
    #print(f"The lattitude is: {lat}") 
    
    # Randomly generate longitude
    lng_pos = random.randint(0,2)
    base_lng = random.randint(0,181)
    dec_lng = random.random()/100
    lng = base_lng + dec_lng
    if lng_pos == 1:
        lng = lng * -1
    #print(f"The longitude is: {lng}") 
    
    # Call citipy file to get nearest city based on random lat and lng
    city = citipy.nearest_city(lat, lng)
    
    # Test to see if the random city is already in the list, if not, add it to the city and country lists
    foundCity = False
    for j in range(len(random_city)):
        if city.city_name == random_city[j]:
            foundCity = True
    if foundCity==False  :   
        random_city.append(city.city_name)
        random_country.append(city.country_code)

# %%
# Build query Url
base_url = "http://api.openweathermap.org/data/2.5/weather?"

units = "imperial"

query_url = base_url + "appid=" + API + "&units=" + units + "&q="

# %%
# Loop through the list of cities and perform request for data on each
search_data = []
cityList = []
countryList = []

searchCnt = 0
print("API Call for OpenWeather Database ")

for city in random_city:
    searchCnt += 1
    print(f"Processing data {searchCnt} for: {city}")   
    response = requests.get(query_url + city).json()
    searchCityID = response.get("id")
    if response.get("id"):
        print(f"     weather data found for: {city}    city id: {searchCityID}")
        search_data.append(response)
        cityList.append(city)
        countryList.append(random_country[searchCnt-1])
    else:
        print(f"     No weather data found for city: {city}")
          

print("Finished!")
# Out:
# API Call for OpenWeather Database
# Processing data 1 for: meyungs
#      No weather data found for city: meyungs
# Processing data 2 for: ushuaia
#      weather data found for: ushuaia    city id: 3833367
# Processing data 3 for: dikson
#      weather data found for: dikson    city id: 1507390
# Processing data 4 for: souillac
#      weather data found for: souillac    city id: 3026644
# Processing data 5 for: margate
#      weather data found for: margate    city id: 2158744
# Processing data 6 for: kaitangata
#      weather data found for: kaitangata    city id: 2208248
# Processing data 7 for: beringovskiy
#      weather data found for: beringovskiy    city id: 2126710
# Processing data 8 for: hilo
#      weather data found for: hilo    city id: 5855927
# Processing data 9 for: ilulissat
#      weather data found for: ilulissat    city id: 3423146
# Processing data 10 for: hovd
#      weather data found for: hovd    city id: 7626384
# Processing data 11 for: mecca
#      weather data found for: mecca    city id: 104515
# Processing data 12 for: pesaro
#      weather data found for: pesaro    city id: 3171173
# Processing data 13 for: kieta
#      weather data found for: kieta    city id: 2094027
# Processing data 14 for: fairbanks
#      weather data found for: fairbanks    city id: 5861897
# Processing data 15 for: port macquarie
#      weather data found for: port macquarie    city id: 2152659
# Processing data 16 for: geraldton
#      weather data found for: geraldton    city id: 5960603
# Processing data 17 for: kapaa
#      weather data found for: kapaa    city id: 5848280
# Processing data 18 for: rikitea
#      weather data found for: rikitea    city id: 4030556
# Processing data 19 for: kizukuri
#      weather data found for: kizukuri    city id: 2129513
# Processing data 20 for: faya
#      weather data found for: faya    city id: 110690
# Processing data 21 for: vaini
#      weather data found for: vaini    city id: 1273574
# Processing data 22 for: kodiak
#      weather data found for: kodiak    city id: 4407665
# Processing data 23 for: pangkalanbuun
#      weather data found for: pangkalanbuun    city id: 1632694
# Processing data 24 for: dudinka
#      weather data found for: dudinka    city id: 1507116
# Processing data 25 for: vuktyl
#      weather data found for: vuktyl    city id: 470905
# Processing data 26 for: aflu
#      No weather data found for city: aflu
# Processing data 27 for: khatanga
#      weather data found for: khatanga    city id: 2022572
# Processing data 28 for: san cristobal
#      weather data found for: san cristobal    city id: 3652462
# Processing data 29 for: albany
#      weather data found for: albany    city id: 5106834
# Processing data 30 for: zhanaozen
#      weather data found for: zhanaozen    city id: 607610
# Processing data 31 for: waingapu
#      weather data found for: waingapu    city id: 1622318
# Processing data 32 for: mataura
#      weather data found for: mataura    city id: 6201424
# Processing data 33 for: can tho
#      weather data found for: can tho    city id: 1586203
# Processing data 34 for: mahebourg
#      weather data found for: mahebourg    city id: 934322
# Processing data 35 for: husavik
#      weather data found for: husavik    city id: 5961417
# Processing data 36 for: klaksvik
#      weather data found for: klaksvik    city id: 2618795
# Processing data 37 for: salinopolis
#      weather data found for: salinopolis    city id: 3389822
# Processing data 38 for: talnakh
#      weather data found for: talnakh    city id: 1490256
# Processing data 39 for: nikolskoye
#      weather data found for: nikolskoye    city id: 546105
# Processing data 40 for: paamiut
#      weather data found for: paamiut    city id: 3421193
# Processing data 41 for: norman wells
#      weather data found for: norman wells    city id: 6089245
# Processing data 42 for: severo-kurilsk
#      weather data found for: severo-kurilsk    city id: 2121385
# Processing data 43 for: laguna
#      weather data found for: laguna    city id: 4013704
# Processing data 44 for: iqaluit
#      weather data found for: iqaluit    city id: 5983720
# Processing data 45 for: kysyl-syr
#      weather data found for: kysyl-syr    city id: 2021017
# Processing data 46 for: bandarbeyla
#      weather data found for: bandarbeyla    city id: 64814
# Processing data 47 for: jamestown
#      weather data found for: jamestown    city id: 2069194
# Processing data 48 for: barrow
#      weather data found for: barrow    city id: 3833859
# Processing data 49 for: bluff
#      weather data found for: bluff    city id: 2175403
# Processing data 50 for: grand river south east
#      No weather data found for city: grand river south east
# Processing data 51 for: madison
#      weather data found for: madison    city id: 5261457
# Processing data 52 for: cidreira
#      weather data found for: cidreira    city id: 3466165
# Processing data 53 for: narsaq
#      weather data found for: narsaq    city id: 3421719
# Processing data 54 for: punta arenas
#      weather data found for: punta arenas    city id: 3874787
# Processing data 55 for: edd
#      weather data found for: edd    city id: 338345
# Processing data 56 for: torbay
#      weather data found for: torbay    city id: 6167817
# Processing data 57 for: cherskiy
#      weather data found for: cherskiy    city id: 2126199
# Processing data 58 for: mantua
#      weather data found for: mantua    city id: 3174050
# Processing data 59 for: solnechnyy
#      weather data found for: solnechnyy    city id: 2016307
# Processing data 60 for: victoria
#      weather data found for: victoria    city id: 1733782
# Processing data 61 for: severnyy-kospashskiy
#      weather data found for: severnyy-kospashskiy    city id: 496307
# Processing data 62 for: pangody
#      weather data found for: pangody    city id: 1495626
# Processing data 63 for: mehamn
#      weather data found for: mehamn    city id: 778707
# Processing data 64 for: sorvag
#      No weather data found for city: sorvag
# Processing data 65 for: mikuni
#      weather data found for: mikuni    city id: 1857260
# Processing data 66 for: patan
#      weather data found for: patan    city id: 1282931
# Processing data 67 for: hambantota
#      weather data found for: hambantota    city id: 1244926
# Processing data 68 for: port alfred
#      weather data found for: port alfred    city id: 964432
# Processing data 69 for: alice springs
#      weather data found for: alice springs    city id: 2077895
# Processing data 70 for: berlevag
#      weather data found for: berlevag    city id: 780687
# Processing data 71 for: morro bay
#      weather data found for: morro bay    city id: 5374920
# Processing data 72 for: hithadhoo
#      weather data found for: hithadhoo    city id: 1282256
# Processing data 73 for: yellowknife
#      weather data found for: yellowknife    city id: 6185377
# Processing data 74 for: chibombo
#      weather data found for: chibombo    city id: 920233
# Processing data 75 for: saskylakh
#      weather data found for: saskylakh    city id: 2017155
# Processing data 76 for: jinchang
#      weather data found for: jinchang    city id: 1805733
# Processing data 77 for: ketchikan
#      weather data found for: ketchikan    city id: 5554428
# Processing data 78 for: opuwo
#      weather data found for: opuwo    city id: 3354077
# Processing data 79 for: riyadh
#      weather data found for: riyadh    city id: 108410
# Processing data 80 for: longyearbyen
#      weather data found for: longyearbyen    city id: 2729907
# Processing data 81 for: airai
#      weather data found for: airai    city id: 1651810
# Processing data 82 for: belushya guba
#      No weather data found for city: belushya guba
# Processing data 83 for: cape town
#      weather data found for: cape town    city id: 3369157
# Processing data 84 for: port elizabeth
#      weather data found for: port elizabeth    city id: 4501427
# Processing data 85 for: coquimbo
#      weather data found for: coquimbo    city id: 3893629
# Processing data 86 for: mandan
#      weather data found for: mandan    city id: 5690366
# Processing data 87 for: amudat
#      weather data found for: amudat    city id: 235191
# Processing data 88 for: imbituba
#      weather data found for: imbituba    city id: 3461370
# Processing data 89 for: liniere
#      No weather data found for city: liniere
# Processing data 90 for: ust-omchug
#      weather data found for: ust-omchug    city id: 2120047
# Processing data 91 for: portland
#      weather data found for: portland    city id: 5746545
# Processing data 92 for: nizhneyansk
#      No weather data found for city: nizhneyansk
# Processing data 93 for: rawson
#      weather data found for: rawson    city id: 3839307
# Processing data 94 for: busselton
#      weather data found for: busselton    city id: 2075265
# Processing data 95 for: katsuura
#      weather data found for: katsuura    city id: 1865309
# Processing data 96 for: naze
#      weather data found for: naze    city id: 2337542
# Processing data 97 for: provideniya
#      weather data found for: provideniya    city id: 4031574
# Processing data 98 for: hobart
#      weather data found for: hobart    city id: 2163355
# Processing data 99 for: russkaya polyana
#      weather data found for: russkaya polyana    city id: 1493423
# Processing data 100 for: malatya
#      No weather data found for city: malatya
# Processing data 101 for: pangnirtung
#      weather data found for: pangnirtung    city id: 6096551
# Processing data 102 for: lorengau
#      weather data found for: lorengau    city id: 2092164
# Processing data 103 for: chokurdakh
#      weather data found for: chokurdakh    city id: 2126123
# Processing data 104 for: waipawa
#      weather data found for: waipawa    city id: 2185329
# Processing data 105 for: makakilo city
#      weather data found for: makakilo city    city id: 5850554
# Processing data 106 for: bartica
#      weather data found for: bartica    city id: 3379507
# Processing data 107 for: chara
#      weather data found for: chara    city id: 262462
# Processing data 108 for: vanimo
#      weather data found for: vanimo    city id: 2084442
# Processing data 109 for: hamilton
#      weather data found for: hamilton    city id: 5969785
# Processing data 110 for: kabalo
#      weather data found for: kabalo    city id: 215668
# Processing data 111 for: lagoa
#      weather data found for: lagoa    city id: 2267254
# Processing data 112 for: kumeny
#      weather data found for: kumeny    city id: 539284
# Processing data 113 for: burgeo
#      weather data found for: burgeo    city id: 5911440
# Processing data 114 for: tasiilaq
#      weather data found for: tasiilaq    city id: 3424607
# Processing data 115 for: east london
#      weather data found for: east london    city id: 1006984
# Processing data 116 for: karlshamn
#      weather data found for: karlshamn    city id: 2701727
# Processing data 117 for: lompoc
#      weather data found for: lompoc    city id: 5367788
# Processing data 118 for: litovko
#      weather data found for: litovko    city id: 2020738
# Processing data 119 for: puerto ayora
#      weather data found for: puerto ayora    city id: 3652764
# Processing data 120 for: leland
#      weather data found for: leland    city id: 4910543
# Processing data 121 for: mar del plata
#      weather data found for: mar del plata    city id: 3863379
# Processing data 122 for: barentsburg
#      No weather data found for city: barentsburg
# Processing data 123 for: mareeba
#      weather data found for: mareeba    city id: 2158767
# Processing data 124 for: waw
#      No weather data found for city: waw
# Processing data 125 for: maraa
#      weather data found for: maraa    city id: 3663475
# Processing data 126 for: fagersta
#      weather data found for: fagersta    city id: 2715656
# Processing data 127 for: safonovo
#      weather data found for: safonovo    city id: 499452
# Processing data 128 for: gat
#      weather data found for: gat    city id: 2249901
# Processing data 129 for: richards bay
#      weather data found for: richards bay    city id: 962367
# Processing data 130 for: nong phai
#      weather data found for: nong phai    city id: 1608191
# Processing data 131 for: meulaboh
#      weather data found for: meulaboh    city id: 1214488
# Processing data 132 for: hermanus
#      weather data found for: hermanus    city id: 3366880
# Processing data 133 for: abha
#      weather data found for: abha    city id: 110690
# Processing data 134 for: buala
#      weather data found for: buala    city id: 2109528
# Processing data 135 for: kokopo
#      weather data found for: kokopo    city id: 2093685
# Processing data 136 for: sentyabrskiy
#      No weather data found for city: sentyabrskiy
# Processing data 137 for: pravda
#      weather data found for: pravda    city id: 728016
# Processing data 138 for: bernalillo
#      weather data found for: bernalillo    city id: 5457198
# Processing data 139 for: seoul
#      weather data found for: seoul    city id: 1835848
# Processing data 140 for: srednekolymsk
#      weather data found for: srednekolymsk    city id: 2121025
# Processing data 141 for: tsihombe
#      No weather data found for city: tsihombe
# Processing data 142 for: taolanaro
#      No weather data found for city: taolanaro
# Processing data 143 for: vardo
#      weather data found for: vardo    city id: 4372777
# Processing data 144 for: asbe teferi
#      weather data found for: asbe teferi    city id: 343402
# Processing data 145 for: atuona
#      weather data found for: atuona    city id: 4020109
# Processing data 146 for: novosibirsk
#      weather data found for: novosibirsk    city id: 1496747
# Processing data 147 for: tuktoyaktuk
#      weather data found for: tuktoyaktuk    city id: 6170031
# Processing data 148 for: carutapera
#      weather data found for: carutapera    city id: 3402648
# Processing data 149 for: illoqqortoormiut
#      No weather data found for city: illoqqortoormiut
# Processing data 150 for: gambela
#      weather data found for: gambela    city id: 337405
# Processing data 151 for: iquique
#      weather data found for: iquique    city id: 3887127
# Processing data 152 for: avarua
#      weather data found for: avarua    city id: 4035715
# Processing data 153 for: vaitupu
#      No weather data found for city: vaitupu
# Processing data 154 for: senno
#      weather data found for: senno    city id: 554873
# Processing data 155 for: fortuna
#      weather data found for: fortuna    city id: 2517679
# Processing data 156 for: umm lajj
#      weather data found for: umm lajj    city id: 100926
# Processing data 157 for: khash
#      weather data found for: khash    city id: 1160571
# Processing data 158 for: katobu
#      weather data found for: katobu    city id: 1640972
# Processing data 159 for: la colorada
#      weather data found for: la colorada    city id: 3628952
# Processing data 160 for: sabang
#      weather data found for: sabang    city id: 1691355
# Processing data 161 for: olafsvik
#      No weather data found for city: olafsvik
# Processing data 162 for: pervomayskoye
#      weather data found for: pervomayskoye    city id: 1495256
# Processing data 163 for: lokoja
#      weather data found for: lokoja    city id: 2331939
# Processing data 164 for: bredasdorp
#      weather data found for: bredasdorp    city id: 1015776
# Processing data 165 for: auki
#      weather data found for: auki    city id: 2339937
# Processing data 166 for: kavieng
#      weather data found for: kavieng    city id: 2094342
# Processing data 167 for: arkhangelsk
#      weather data found for: arkhangelsk    city id: 581049
# Processing data 168 for: ardakan
#      weather data found for: ardakan    city id: 143073
# Processing data 169 for: bani walid
#      weather data found for: bani walid    city id: 2218840
# Processing data 170 for: leningradskiy
#      weather data found for: leningradskiy    city id: 2123814
# Processing data 171 for: southbridge
#      weather data found for: southbridge    city id: 4951594
# Processing data 172 for: gravdal
#      weather data found for: gravdal    city id: 3147822
# Processing data 173 for: mbandaka
#      weather data found for: mbandaka    city id: 2312895
# Processing data 174 for: zabaykalsk
#      weather data found for: zabaykalsk    city id: 2012780
# Processing data 175 for: barra patuca
#      weather data found for: barra patuca    city id: 3614835
# Processing data 176 for: kabo
#      weather data found for: kabo    city id: 2386042
# Processing data 177 for: upernavik
#      weather data found for: upernavik    city id: 3418910
# Processing data 178 for: saint george
#      weather data found for: saint george    city id: 262462
# Processing data 179 for: saldanha
#      weather data found for: saldanha    city id: 2737599
# Processing data 180 for: maltahohe
#      weather data found for: maltahohe    city id: 3355624
# Processing data 181 for: gamba
#      weather data found for: gamba    city id: 1281256
# Processing data 182 for: isiro
#      weather data found for: isiro    city id: 215771
# Processing data 183 for: mahenge
#      weather data found for: mahenge    city id: 155274
# Processing data 184 for: necochea
#      weather data found for: necochea    city id: 3430443
# Processing data 185 for: mogadishu
#      weather data found for: mogadishu    city id: 53654
# Processing data 186 for: peruibe
#      weather data found for: peruibe    city id: 3454061
# Processing data 187 for: silvan
#      weather data found for: silvan    city id: 300796
# Processing data 188 for: tiksi
#      weather data found for: tiksi    city id: 2015306
# Processing data 189 for: sorland
#      weather data found for: sorland    city id: 3137469
# Processing data 190 for: mangan
#      weather data found for: mangan    city id: 1263776
# Processing data 191 for: coulihaut
#      No weather data found for city: coulihaut
# Processing data 192 for: goba
#      weather data found for: goba    city id: 336350
# Processing data 193 for: esso
#      weather data found for: esso    city id: 2125711
# Processing data 194 for: kankon
#      weather data found for: kankon    city id: 1268022
# Processing data 195 for: cervo
#      weather data found for: cervo    city id: 3469169
# Processing data 196 for: mahadday weyne
#      No weather data found for city: mahadday weyne
# Processing data 197 for: along
#      weather data found for: along    city id: 1278969
# Processing data 198 for: kodinsk
#      weather data found for: kodinsk    city id: 1503037
# Processing data 199 for: khasan
#      weather data found for: khasan    city id: 2039557
# Processing data 200 for: kawalu
#      weather data found for: kawalu    city id: 1640902
# Processing data 201 for: raipur
#      weather data found for: raipur    city id: 1258980
# Processing data 202 for: havoysund
#      weather data found for: havoysund    city id: 779622
# Processing data 203 for: carnarvon
#      weather data found for: carnarvon    city id: 1014034
# Processing data 204 for: butaritari
#      weather data found for: butaritari    city id: 2110227
# Processing data 205 for: luderitz
#      weather data found for: luderitz    city id: 3355672
# Processing data 206 for: russell
#      weather data found for: russell    city id: 3844421
# Processing data 207 for: amderma
#      No weather data found for city: amderma
# Processing data 208 for: la ronge
#      weather data found for: la ronge    city id: 6050066
# Processing data 209 for: znamenskoye
#      weather data found for: znamenskoye    city id: 1485020
# Processing data 210 for: doha
#      weather data found for: doha    city id: 290030
# Processing data 211 for: yulara
#      weather data found for: yulara    city id: 6355222
# Processing data 212 for: camacha
#      weather data found for: camacha    city id: 2270385
# Processing data 213 for: rosetta
#      weather data found for: rosetta    city id: 350203
# Processing data 214 for: tuggurt
#      No weather data found for city: tuggurt
# Processing data 215 for: mirzapur
#      weather data found for: mirzapur    city id: 1262995
# Processing data 216 for: bengkulu
#      No weather data found for city: bengkulu
# Processing data 217 for: new norfolk
#      weather data found for: new norfolk    city id: 2155415
# Processing data 218 for: anuchino
#      weather data found for: anuchino    city id: 2027596
# Processing data 219 for: sangar
#      weather data found for: sangar    city id: 2017215
# Processing data 220 for: ndago
#      weather data found for: ndago    city id: 226600
# Processing data 221 for: varias
#      weather data found for: varias    city id: 663171
# Processing data 222 for: cap malheureux
#      weather data found for: cap malheureux    city id: 934649
# Processing data 223 for: san patricio
#      weather data found for: san patricio    city id: 3437029
# Processing data 224 for: kruisfontein
#      weather data found for: kruisfontein    city id: 986717
# Processing data 225 for: severo-yeniseyskiy
#      weather data found for: severo-yeniseyskiy    city id: 1492566
# Processing data 226 for: nyurba
#      weather data found for: nyurba    city id: 2018735
# Processing data 227 for: xining
#      weather data found for: xining    city id: 1788852
# Processing data 228 for: pacasmayo
#      weather data found for: pacasmayo    city id: 3694178
# Processing data 229 for: xiongzhou
#      weather data found for: xiongzhou    city id: 6957998
# Processing data 230 for: champerico
#      weather data found for: champerico    city id: 3530097
# Processing data 231 for: zaraza
#      weather data found for: zaraza    city id: 3625066
# Processing data 232 for: aykhal
#      weather data found for: aykhal    city id: 2027296
# Processing data 233 for: bairiki
#      No weather data found for city: bairiki
# Processing data 234 for: muli
#      weather data found for: muli    city id: 1256929
# Processing data 235 for: ponta do sol
#      weather data found for: ponta do sol    city id: 3453439
# Processing data 236 for: jiuquan
#      weather data found for: jiuquan    city id: 1280957
# Processing data 237 for: thompson
#      weather data found for: thompson    city id: 6165406
# Processing data 238 for: kavaratti
#      weather data found for: kavaratti    city id: 1267390
# Processing data 239 for: attawapiskat
#      No weather data found for city: attawapiskat
# Processing data 240 for: sept-iles
#      weather data found for: sept-iles    city id: 6144312
# Processing data 241 for: eydhafushi
#      weather data found for: eydhafushi    city id: 1337606
# Processing data 242 for: bethel
#      weather data found for: bethel    city id: 5880568
# Processing data 243 for: buchanan
#      weather data found for: buchanan    city id: 2278158
# Processing data 244 for: mundgod
#      weather data found for: mundgod    city id: 1262510
# Processing data 245 for: selenduma
#      weather data found for: selenduma    city id: 2017063
# Processing data 246 for: bayog
#      weather data found for: bayog    city id: 1725747
# Processing data 247 for: nanortalik
#      weather data found for: nanortalik    city id: 3421765
# Processing data 248 for: takapau
#      weather data found for: takapau    city id: 2181988
# Processing data 249 for: malacacheta
#      weather data found for: malacacheta    city id: 3458121
# Processing data 250 for: saint-philippe
#      weather data found for: saint-philippe    city id: 6138908
# Processing data 251 for: namtsy
#      weather data found for: namtsy    city id: 2019488
# Processing data 252 for: calamar
#      weather data found for: calamar    city id: 3687975
# Processing data 253 for: bilma
#      weather data found for: bilma    city id: 2446796
# Processing data 254 for: hami
#      weather data found for: hami    city id: 1529484
# Processing data 255 for: nanchang
#      weather data found for: nanchang    city id: 1800163
# Processing data 256 for: suicheng
#      weather data found for: suicheng    city id: 1793899
# Processing data 257 for: bambous virieux
#      weather data found for: bambous virieux    city id: 1106677
# Processing data 258 for: flinders
#      weather data found for: flinders    city id: 6255012
# Processing data 259 for: kaili
#      weather data found for: kaili    city id: 1638368
# Processing data 260 for: kenai
#      weather data found for: kenai    city id: 5866063
# Processing data 261 for: nanaimo
#      weather data found for: nanaimo    city id: 6085772
# Processing data 262 for: karaul
#      No weather data found for city: karaul
# Processing data 263 for: high rock
#      weather data found for: high rock    city id: 3572189
# Processing data 264 for: dingle
#      weather data found for: dingle    city id: 1714733
# Processing data 265 for: poum
#      weather data found for: poum    city id: 787487
# Processing data 266 for: mount isa
#      weather data found for: mount isa    city id: 2065594
# Processing data 267 for: qui nhon
#      No weather data found for city: qui nhon
# Processing data 268 for: kushmurun
#      No weather data found for city: kushmurun
# Processing data 269 for: surab
#      weather data found for: surab    city id: 1164306
# Processing data 270 for: wenling
#      weather data found for: wenling    city id: 1791464
# Processing data 271 for: rochegda
#      weather data found for: rochegda    city id: 501847
# Processing data 272 for: codrington
#      weather data found for: codrington    city id: 2160063
# Processing data 273 for: buraydah
#      weather data found for: buraydah    city id: 107304
# Processing data 274 for: diest
#      weather data found for: diest    city id: 2799398
# Processing data 275 for: grand gaube
#      weather data found for: grand gaube    city id: 934479
# Processing data 276 for: yarmouth
#      weather data found for: yarmouth    city id: 2633414
# Processing data 277 for: pevek
#      weather data found for: pevek    city id: 2122090
# Processing data 278 for: tukan
#      weather data found for: tukan    city id: 480637
# Processing data 279 for: ituni
#      No weather data found for city: ituni
# Processing data 280 for: alexandria
#      weather data found for: alexandria    city id: 4314550
# Processing data 281 for: arraial do cabo
#      weather data found for: arraial do cabo    city id: 3471451
# Processing data 282 for: lebu
#      weather data found for: lebu    city id: 344979
# Processing data 283 for: asfi
#      No weather data found for city: asfi
# Processing data 284 for: hasaki
#      weather data found for: hasaki    city id: 2112802
# Processing data 285 for: lima
#      weather data found for: lima    city id: 3936456
# Processing data 286 for: stornoway
#      No weather data found for city: stornoway
# Processing data 287 for: sol-iletsk
#      weather data found for: sol-iletsk    city id: 491019
# Processing data 288 for: sobolevo
#      weather data found for: sobolevo    city id: 525426
# Processing data 289 for: hit
#      weather data found for: hit    city id: 95788
# Processing data 290 for: bandar
#      weather data found for: bandar    city id: 1649593
# Processing data 291 for: nome
#      weather data found for: nome    city id: 4732862
# Processing data 292 for: padang
#      weather data found for: padang    city id: 1633419
# Processing data 293 for: constantine
#      weather data found for: constantine    city id: 2501152
# Processing data 294 for: castro
#      weather data found for: castro    city id: 3896218
# Processing data 295 for: santa rosa
#      weather data found for: santa rosa    city id: 3835994
# Processing data 296 for: namatanai
#      weather data found for: namatanai    city id: 2090021
# Processing data 297 for: topsham
#      weather data found for: topsham    city id: 2635680
# Processing data 298 for: sitka
#      weather data found for: sitka    city id: 4267710
# Processing data 299 for: cabo san lucas
#      weather data found for: cabo san lucas    city id: 3985710
# Processing data 300 for: ostrovnoy
#      weather data found for: ostrovnoy    city id: 556268
# Processing data 301 for: palu
#      weather data found for: palu    city id: 1633034
# Processing data 302 for: thinadhoo
#      weather data found for: thinadhoo    city id: 1337610
# Processing data 303 for: wagar
#      weather data found for: wagar    city id: 4069458
# Processing data 304 for: zhangye
#      weather data found for: zhangye    city id: 1785036
# Processing data 305 for: sayyan
#      weather data found for: sayyan    city id: 70979
# Processing data 306 for: taveta
#      weather data found for: taveta    city id: 179525
# Processing data 307 for: port lincoln
#      weather data found for: port lincoln    city id: 2063036
# Processing data 308 for: kyra
#      No weather data found for city: kyra
# Processing data 309 for: erzin
#      weather data found for: erzin    city id: 296852
# Processing data 310 for: sogdiondon
#      No weather data found for city: sogdiondon
# Processing data 311 for: ennis
#      weather data found for: ennis    city id: 2964405
# Processing data 312 for: karachi
#      weather data found for: karachi    city id: 1174872
# Processing data 313 for: saint-louis
#      weather data found for: saint-louis    city id: 2978742
# Processing data 314 for: labuhan
#      weather data found for: labuhan    city id: 1641899
# Processing data 315 for: sciacca
#      weather data found for: sciacca    city id: 6542103
# Processing data 316 for: mrirt
#      No weather data found for city: mrirt
# Processing data 317 for: port blair
#      weather data found for: port blair    city id: 1259385
# Processing data 318 for: sampit
#      weather data found for: sampit    city id: 1628884
# Processing data 319 for: kazalinsk
#      No weather data found for city: kazalinsk
# Processing data 320 for: vila
#      weather data found for: vila    city id: 3164565
# Processing data 321 for: moree
#      weather data found for: moree    city id: 2156927
# Processing data 322 for: hirara
#      weather data found for: hirara    city id: 1862505
# Processing data 323 for: wageningen
#      weather data found for: wageningen    city id: 2745088
# Processing data 324 for: carlton
#      weather data found for: carlton    city id: 5020428
# Processing data 325 for: evensk
#      weather data found for: evensk    city id: 2125693
# Processing data 326 for: yekaterinovka
#      weather data found for: yekaterinovka    city id: 488635
# Processing data 327 for: ahuimanu
#      weather data found for: ahuimanu    city id: 5856516
# Processing data 328 for: constitucion
#      weather data found for: constitucion    city id: 4011743
# Processing data 329 for: herat
#      weather data found for: herat    city id: 1140026
# Processing data 330 for: sovetskiy
#      weather data found for: sovetskiy    city id: 490040
# Processing data 331 for: aswan
#      weather data found for: aswan    city id: 359792
# Processing data 332 for: pacific grove
#      weather data found for: pacific grove    city id: 5380437
# Processing data 333 for: nouna
#      weather data found for: nouna    city id: 2357163
# Processing data 334 for: nikki
#      weather data found for: nikki    city id: 2392505
# Processing data 335 for: bako
#      weather data found for: bako    city id: 2330100
# Processing data 336 for: ribeira grande
#      weather data found for: ribeira grande    city id: 3372707
# Processing data 337 for: lambarene
#      weather data found for: lambarene    city id: 2399888
# Processing data 338 for: qaanaaq
#      weather data found for: qaanaaq    city id: 3831208
# Processing data 339 for: sioux lookout
#      weather data found for: sioux lookout    city id: 6148373
# Processing data 340 for: saleaula
#      No weather data found for city: saleaula
# Processing data 341 for: kasangulu
#      weather data found for: kasangulu    city id: 2315057
# Processing data 342 for: utiroa
#      No weather data found for city: utiroa
# Processing data 343 for: westerland
#      weather data found for: westerland    city id: 2757220
# Processing data 344 for: nizwa
#      weather data found for: nizwa    city id: 286987
# Processing data 345 for: miyako
#      weather data found for: miyako    city id: 1848087
# Processing data 346 for: yuzhnyy
#      weather data found for: yuzhnyy    city id: 526543
# Processing data 347 for: henties bay
#      weather data found for: henties bay    city id: 3356832
# Processing data 348 for: at-bashi
#      weather data found for: at-bashi    city id: 1528796
# Processing data 349 for: lakes entrance
#      weather data found for: lakes entrance    city id: 2160735
# Processing data 350 for: mnogovershinnyy
#      weather data found for: mnogovershinnyy    city id: 2019935
# Processing data 351 for: cerro largo
#      weather data found for: cerro largo    city id: 3466395
# Processing data 352 for: sumbawa
#      No weather data found for city: sumbawa
# Processing data 353 for: georgetown
#      weather data found for: georgetown    city id: 3378644
# Processing data 354 for: yining
#      weather data found for: yining    city id: 1786538
# Processing data 355 for: nuuk
#      weather data found for: nuuk    city id: 3421319
# Processing data 356 for: karamay
#      No weather data found for city: karamay
# Processing data 357 for: yian
#      No weather data found for city: yian
# Processing data 358 for: sulangan
#      weather data found for: sulangan    city id: 1685422
# Processing data 359 for: korla
#      No weather data found for city: korla
# Processing data 360 for: chuy
#      weather data found for: chuy    city id: 3443061
# Processing data 361 for: voyvozh
#      weather data found for: voyvozh    city id: 471308
# Processing data 362 for: lexington park
#      weather data found for: lexington park    city id: 4360592
# Processing data 363 for: moose factory
#      weather data found for: moose factory    city id: 6078372
# Processing data 364 for: palembang
#      weather data found for: palembang    city id: 1633070
# Processing data 365 for: sao jose da coroa grande
#      weather data found for: sao jose da coroa grande    city id: 3388456
# Processing data 366 for: preobrazheniye
#      weather data found for: preobrazheniye    city id: 2017658
# Processing data 367 for: lewisporte
#      weather data found for: lewisporte    city id: 6053446
# Processing data 368 for: goure
#      weather data found for: goure    city id: 2444219
# Processing data 369 for: mirnyy
#      weather data found for: mirnyy    city id: 502265
# Processing data 370 for: talara
#      weather data found for: talara    city id: 3691582
# Processing data 371 for: adrar
#      weather data found for: adrar    city id: 2508813
# Processing data 372 for: darhan
#      weather data found for: darhan    city id: 2031964
# Processing data 373 for: matara
#      weather data found for: matara    city id: 3948642
# Processing data 374 for: moyale
#      weather data found for: moyale    city id: 186180
# Processing data 375 for: yar-sale
#      weather data found for: yar-sale    city id: 1486321
# Processing data 376 for: ambikapur
#      weather data found for: ambikapur    city id: 1278827
# Processing data 377 for: saint-francois
#      weather data found for: saint-francois    city id: 2980080
# Processing data 378 for: fort saint john
#      No weather data found for city: fort saint john
# Processing data 379 for: tyup
#      weather data found for: tyup    city id: 1527121
# Processing data 380 for: kropotkin
#      weather data found for: kropotkin    city id: 540761
# Processing data 381 for: ayutla
#      weather data found for: ayutla    city id: 4017924
# Processing data 382 for: tura
#      weather data found for: tura    city id: 1254046
# Processing data 383 for: bereda
#      weather data found for: bereda    city id: 3105522
# Processing data 384 for: barawe
#      No weather data found for city: barawe
# Processing data 385 for: monterey
#      weather data found for: monterey    city id: 5374361
# Processing data 386 for: tongren
#      weather data found for: tongren    city id: 1792592
# Processing data 387 for: honningsvag
#      weather data found for: honningsvag    city id: 779554
# Processing data 388 for: guerrero negro
#      weather data found for: guerrero negro    city id: 4021858
# Processing data 389 for: araouane
#      weather data found for: araouane    city id: 2460954
# Processing data 390 for: nagato
#      weather data found for: nagato    city id: 1899102
# Processing data 391 for: prince albert
#      weather data found for: prince albert    city id: 6113335
# Processing data 392 for: bathsheba
#      weather data found for: bathsheba    city id: 3374083
# Processing data 393 for: suntar
#      weather data found for: suntar    city id: 2015913
# Processing data 394 for: skegness
#      weather data found for: skegness    city id: 2637762
# Processing data 395 for: sayanskiy
#      No weather data found for city: sayanskiy
# Processing data 396 for: wajima
#      weather data found for: wajima    city id: 1848976
# Processing data 397 for: tabarqah
#      No weather data found for city: tabarqah
# Processing data 398 for: yerky
#      weather data found for: yerky    city id: 701075
# Processing data 399 for: bilibino
#      weather data found for: bilibino    city id: 2126682
# Processing data 400 for: nurota
#      weather data found for: nurota    city id: 1513087
# Processing data 401 for: petropavlovsk-kamchatskiy
#      weather data found for: petropavlovsk-kamchatskiy    city id: 2122104
# Processing data 402 for: inhambane
#      weather data found for: inhambane    city id: 1045114
# Processing data 403 for: aktas
#      No weather data found for city: aktas
# Processing data 404 for: vestmannaeyjar
#      weather data found for: vestmannaeyjar    city id: 3412093
# Processing data 405 for: toora-khem
#      weather data found for: toora-khem    city id: 1489401
# Processing data 406 for: salym
#      weather data found for: salym    city id: 1493162
# Processing data 407 for: chernyshevskiy
#      weather data found for: chernyshevskiy    city id: 2025456
# Processing data 408 for: acapulco
#      weather data found for: acapulco    city id: 3533462
# Processing data 409 for: salalah
#      weather data found for: salalah    city id: 286621
# Processing data 410 for: irbil
#      No weather data found for city: irbil
# Processing data 411 for: aklavik
#      weather data found for: aklavik    city id: 5882953
# Processing data 412 for: povarovo
#      weather data found for: povarovo    city id: 505824
# Processing data 413 for: jamsa
#      weather data found for: jamsa    city id: 656083
# Processing data 414 for: san quintin
#      weather data found for: san quintin    city id: 1688687
# Processing data 415 for: rapar
#      weather data found for: rapar    city id: 1258406
# Processing data 416 for: birao
#      weather data found for: birao    city id: 240210
# Processing data 417 for: shubarshi
#      weather data found for: shubarshi    city id: 608270
# Processing data 418 for: nisia floresta
#      weather data found for: nisia floresta    city id: 3393922
# Processing data 419 for: clarence town
#      weather data found for: clarence town    city id: 2171465
# Processing data 420 for: umm kaddadah
#      weather data found for: umm kaddadah    city id: 364933
# Processing data 421 for: beinamar
#      weather data found for: beinamar    city id: 2435708
# Processing data 422 for: balkhash
#      weather data found for: balkhash    city id: 1525798
# Processing data 423 for: yenagoa
#      weather data found for: yenagoa    city id: 2318123
# Processing data 424 for: maningrida
#      weather data found for: maningrida    city id: 2067089
# Processing data 425 for: maryville
#      weather data found for: maryville    city id: 5056172
# Processing data 426 for: kristiansund
#      weather data found for: kristiansund    city id: 6453331
# Processing data 427 for: broken hill
#      weather data found for: broken hill    city id: 2173911
# Processing data 428 for: melita
#      weather data found for: melita    city id: 6071900
# Processing data 429 for: skibbereen
#      weather data found for: skibbereen    city id: 2961459
# Processing data 430 for: thouars
#      weather data found for: thouars    city id: 2972695
# Processing data 431 for: ambulu
#      weather data found for: ambulu    city id: 1621313
# Processing data 432 for: limoux
#      weather data found for: limoux    city id: 2998264
# Processing data 433 for: tongliao
#      weather data found for: tongliao    city id: 2034400
# Processing data 434 for: gari
#      weather data found for: gari    city id: 1506676
# Processing data 435 for: sao felix do xingu
#      weather data found for: sao felix do xingu    city id: 3388847
# Processing data 436 for: ninghai
#      weather data found for: ninghai    city id: 1799384
# Processing data 437 for: tateyama
#      weather data found for: tateyama    city id: 1849876
# Processing data 438 for: bentiu
#      No weather data found for city: bentiu
# Processing data 439 for: santa isabel do rio negro
#      weather data found for: santa isabel do rio negro    city id: 3662489
# Processing data 440 for: beroroha
#      weather data found for: beroroha    city id: 1066831
# Processing data 441 for: tessalit
#      weather data found for: tessalit    city id: 2449893
# Processing data 442 for: namibe
#      weather data found for: namibe    city id: 3347019
# Processing data 443 for: victor harbor
#      weather data found for: victor harbor    city id: 2059470
# Processing data 444 for: gambiran
#      weather data found for: gambiran    city id: 1623251
# Processing data 445 for: phan thiet
#      weather data found for: phan thiet    city id: 1571058
# Processing data 446 for: atambua
#      weather data found for: atambua    city id: 1651103
# Processing data 447 for: birjand
#      weather data found for: birjand    city id: 140463
# Processing data 448 for: shimoda
#      weather data found for: shimoda    city id: 1852357
# Processing data 449 for: kandi
#      weather data found for: kandi    city id: 2393693
# Processing data 450 for: sao filipe
#      weather data found for: sao filipe    city id: 3374210
# Processing data 451 for: gatbo
#      weather data found for: gatbo    city id: 1713131
# Processing data 452 for: bajo baudo
#      No weather data found for city: bajo baudo
# Processing data 453 for: pisco
#      weather data found for: pisco    city id: 3932145
# Processing data 454 for: moerai
#      weather data found for: moerai    city id: 4034188
# Processing data 455 for: hoquiam
#      weather data found for: hoquiam    city id: 5797693
# Processing data 456 for: borovskoy
#      weather data found for: borovskoy    city id: 1525121
# Processing data 457 for: zhigansk
#      weather data found for: zhigansk    city id: 2012530
# Processing data 458 for: chumikan
#      weather data found for: chumikan    city id: 2025256
# Processing data 459 for: tuatapere
#      weather data found for: tuatapere    city id: 2180815
# Processing data 460 for: gushikawa
#      weather data found for: gushikawa    city id: 1863495
# Processing data 461 for: jega
#      weather data found for: jega    city id: 2336237
# Processing data 462 for: sabha
#      weather data found for: sabha    city id: 2212775
# Processing data 463 for: mullaitivu
#      No weather data found for city: mullaitivu
# Processing data 464 for: baie-comeau
#      weather data found for: baie-comeau    city id: 5889745
# Processing data 465 for: tahta
#      No weather data found for city: tahta
# Processing data 466 for: half moon bay
#      weather data found for: half moon bay    city id: 5354943
# Processing data 467 for: caruray
#      weather data found for: caruray    city id: 1718234
# Processing data 468 for: qasigiannguit
#      weather data found for: qasigiannguit    city id: 3420768
# Processing data 469 for: tral
#      weather data found for: tral    city id: 1254198
# Processing data 470 for: kathu
#      weather data found for: kathu    city id: 991664
# Processing data 471 for: vila velha
#      weather data found for: vila velha    city id: 6320062
# Processing data 472 for: warwick
#      weather data found for: warwick    city id: 5225507
# Processing data 473 for: ostersund
#      weather data found for: ostersund    city id: 2685750
# Processing data 474 for: shenjiamen
#      weather data found for: shenjiamen    city id: 1795632
# Processing data 475 for: tromso
#      weather data found for: tromso    city id: 3133895
# Processing data 476 for: rio verde de mato grosso
#      weather data found for: rio verde de mato grosso    city id: 3451051
# Processing data 477 for: ancud
#      weather data found for: ancud    city id: 3899695
# Processing data 478 for: tilichiki
#      weather data found for: tilichiki    city id: 2120591
# Processing data 479 for: sterling
#      weather data found for: sterling    city id: 4787534
# Processing data 480 for: ourossogui
#      weather data found for: ourossogui    city id: 2246922
# Processing data 481 for: burica
#      No weather data found for city: burica
# Processing data 482 for: sorrento
#      weather data found for: sorrento    city id: 2063523
# Processing data 483 for: jever
#      weather data found for: jever    city id: 2894897
# Processing data 484 for: karpogory
#      weather data found for: karpogory    city id: 552256
# Processing data 485 for: halifax
#      weather data found for: halifax    city id: 6324729
# Processing data 486 for: yusva
#      No weather data found for city: yusva
# Processing data 487 for: sindor
#      weather data found for: sindor    city id: 492860
# Processing data 488 for: alyangula
#      weather data found for: alyangula    city id: 2079582
# Processing data 489 for: shingu
#      weather data found for: shingu    city id: 1847947
# Processing data 490 for: rairangpur
#      weather data found for: rairangpur    city id: 1265830
# Processing data 491 for: kloulklubed
#      weather data found for: kloulklubed    city id: 7671223
# Processing data 492 for: raudeberg
#      weather data found for: raudeberg    city id: 3146487
# Processing data 493 for: springbok
#      weather data found for: springbok    city id: 3361142
# Processing data 494 for: faanui
#      weather data found for: faanui    city id: 4034551
# Processing data 495 for: tumannyy
#      No weather data found for city: tumannyy
# Processing data 496 for: boa vista
#      weather data found for: boa vista    city id: 3664980
# Processing data 497 for: catamarca
#      No weather data found for city: catamarca
# Processing data 498 for: nouadhibou
#      weather data found for: nouadhibou    city id: 2377457
# Processing data 499 for: dibaya
#      No weather data found for city: dibaya
# Processing data 500 for: te anau
#      weather data found for: te anau    city id: 2181625
# Finished!

# %%
# Use list comprehension to gather necessary data series

lat_data = [data.get("coord").get("lat") for data in search_data]
lng_data = [data.get("coord").get("lon") for data in search_data]
temp_data = [data.get("main").get("temp") for data in search_data]
humid_data = [data.get("main").get("humidity") for data in search_data]
cloud_data =[data.get("clouds").get("all") for data in search_data]
wind_data = [data.get("wind").get("speed") for data in search_data]

# %%
# Create data frame with aggregated data
weather_data = pd.DataFrame({"cityName":cityList,
                            "country":countryList,
                            "lat":lat_data,
                            "lng":lng_data,
                            "temp":temp_data,
                            "humidity":humid_data,
                            "cloudiness":cloud_data,
                            "winds":wind_data})

# %%
# Force column order
weather_data = weather_data[["cityName","country","lat","lng","temp","humidity","cloudiness","winds"]]
weather_data.head()
# Out:
#      cityName country    lat     lng   temp  humidity  cloudiness  winds
# 0     ushuaia      ar -54.81  -68.31  37.40        59          75   9.60
# 1      dikson      ru  73.51   80.55  37.01       100          68  14.79
# 2    souillac      mu  45.60   -0.60  72.39        64           0   5.82
# 3     margate      za -43.03  147.26  50.00        53          40  21.92
# 4  kaitangata      nz -46.28  169.85  38.63        84          76   6.35

# %%
# Save weather data to csv file
weather_data.to_csv("weatherdata.csv", encoding="utf-8", index=False)

# %%
# Build a scatter plot for each data type

# Latitude vs Max Temp
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# Add chart labels
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Temperature (F) ")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-90,90)

# Save the figure
plt.savefig("Lat_vs_MaxTemp.png")
# Show plot
plt.show()

# %%
# Latitude vs Humidity# Latitu 
plt.scatter(weather_data["lat"], weather_data["humidity"], marker="o")

# Add chart labels
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-90,90)

# Save the figure
plt.savefig("Lat_vs_Humidity.png")

# Show plot
plt.show()

# %%
# Latitude vs Cloudiness
plt.scatter(weather_data["lat"], weather_data["cloudiness"], marker="o")

# Add chart labels
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-90,90)

# Save the figure
plt.savefig("Lat_vs_Cloudiness.png")

# Show plot
plt.show()

# %%
# Latitude vs Wind Speed# Latitu 
plt.scatter(weather_data["lat"], weather_data["winds"], marker="o")

# Add chart labels
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-90,90)

# Save the figure
plt.savefig("Lat_vs_WindSpeed.png")

# Show plot
plt.show()
